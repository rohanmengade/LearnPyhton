# %%
can = "Soda"

# %%
can
# Out:
# 'Soda'

# %%
type(can)
# Out:
# str

# %%
pizza = 100
type(pizza)
# Out:
# int

# %%
can = "Soda"
can = 7.5
can
# Out:
# 7.5

# %%
id(can)
# Out:
# 2305806314288

# %%
can=7.9

# %%
id(can)
# Out:
# 2305806308752

# %%
can = "tin"

# %%
id(tin)
# Out:
# 2305806870176

# %%
name = "Rohan"

# %%
id(name)
# Out:
# 2305808695344

# %%
address = name

# %%
id(address)
# Out:
# 2305808695344
