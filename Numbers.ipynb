# %%
b = 100
h = 50

area = (b*h)/2
area
# Out:
# 2500.0

# %%
type(area)
# Out:
# float

# %%
type(100)
# Out:
# int

# %%
x = 10
y = 3

# %%
x+y
# Out:
# 13

# %%
x-y
# Out:
# 7

# %%
x*y
# Out:
# 30

# %%
x/y  # Division
# Out:
# 3.3333333333333335

# %%
x//y # quotient, integer part of division
# Out:
# 3

# %%
x%y  # it is modulo operator.It gives remainder of division operator
# Out:
# 1

# %%
(x,y)
# Out:
# (10, 3)

# %%
x**y # raised to values
# Out:
# 1000

# %%
10+2*3
# Out:
# 16

# %%
(10+2)*3 # order of operations
# Out:
# 36

# %%
foo = 2.3e4
foo
# Out:
# 23000.0

# %%
1e4
# Out:
# 10000.0

# %%
t = 2.3e-4
t
# Out:
# 0.00023

# %%
1e-3
# Out:
# 0.001

# %%
total = 10+30+50.5

# %%
total
# Out:
# 90.5

# %%
round(total)
# Out:
# 90

# %%
food = 10

# %%
food
# Out:
# 10

# %%
type(food)
# Out:
# int

# %%
food = "10"

# %%
type(food)
# Out:
# str

# %%
float(food)
# Out:
# 10.0

# %%
int(food)
# Out:
# 10

# %%
import math

# %%
x = 16
math.sqrt(x)
# Out:
# 4.0

# %%
math.floor(5.9) # gives floor value of 5.9
# Out:
# 5

# %%
math.ceil(5.9) # gives ceil value of 5.9
# Out:
# 6

# %%
math.pi
# Out:
# 3.141592653589793
